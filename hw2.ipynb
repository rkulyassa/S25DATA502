# %% [markdown]
# # Homework 2
# ## Ryan Kulyassa

# %% [markdown]
# 1. Download the dataset and load it into a new notebook using the `pd.read_csv()` function.

# %%
import pandas as pd

df = pd.read_csv("./data/cereal.csv")

# %% [markdown]
# 2. Recode all the cereal manufacturers to be their full name (e.g. "G" should be replaced with "General Mills", "K" with "Kelloggs", and so forth)

# %%
manufacturer_mapping = {
    "N": "Nabisco",
    "Q": "Quaker Oats",
    "K": "Kelloggs",
    "R": "Ralston",
    "G": "General Mills",
    "P": "Post Consumer Brands"
}

df["mfr"] = df["mfr"].replace(manufacturer_mapping)

df
# Out:
#                          name            mfr type  calories  protein  fat  \
# 0                   100% Bran        Nabisco    C        70        4    1
# 1           100% Natural Bran    Quaker Oats    C       120        3    5
# 2                    All-Bran       Kelloggs    C        70        4    1
# 3   All-Bran with Extra Fiber       Kelloggs    C        50        4    0
# 4              Almond Delight        Ralston    C       110        2    2
# ..                        ...            ...  ...       ...      ...  ...
# 72                    Triples  General Mills    C       110        2    1
# 73                       Trix  General Mills    C       110        1    1
# 74                 Wheat Chex        Ralston    C       100        3    1
# 75                   Wheaties  General Mills    C       100        3    1
# 76        Wheaties Honey Gold  General Mills    C       110        2    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# ...

# %% [markdown]
# 3. Create a dataframe called `df_gm` that contains only cereals manufactured by General Mills.

# %%
df_gm = df[
    df["mfr"] == "General Mills"
]

df_gm
# Out:
#                        name            mfr type  calories  protein  fat  \
# 5   Apple Cinnamon Cheerios  General Mills    C       110        2    2
# 7                   Basic 4  General Mills    C       130        3    2
# 11                 Cheerios  General Mills    C       110        6    2
# 12    Cinnamon Toast Crunch  General Mills    C       120        1    3
# 13                 Clusters  General Mills    C       110        3    2
# 14              Cocoa Puffs  General Mills    C       110        1    1
# 18            Count Chocula  General Mills    C       110        1    1
# 22   Crispy Wheat & Raisins  General Mills    C       100        2    1
# 31           Golden Grahams  General Mills    C       110        1    1
# 36       Honey Nut Cheerios  General Mills    C       110        3    1
# 40                      Kix  General Mills    C       110        2    1
# 42             Lucky Charms  General Mills    C       110        2    1
# ...

# %% [markdown]
# 4. Create a dataframe called `df_gm_k` that contains cereals manufactured by either General Mills or Kelloggs.

# %%
df_gm_k = df[
    df["mfr"].isin(["General Mills", "Kelloggs"])
]

df_gm_k
# Out:
#                            name            mfr type  calories  protein  fat  \
# 2                      All-Bran       Kelloggs    C        70        4    1
# 3     All-Bran with Extra Fiber       Kelloggs    C        50        4    0
# 5       Apple Cinnamon Cheerios  General Mills    C       110        2    2
# 6                   Apple Jacks       Kelloggs    C       110        2    0
# 7                       Basic 4  General Mills    C       130        3    2
# 11                     Cheerios  General Mills    C       110        6    2
# 12        Cinnamon Toast Crunch  General Mills    C       120        1    3
# 13                     Clusters  General Mills    C       110        3    2
# 14                  Cocoa Puffs  General Mills    C       110        1    1
# 16                  Corn Flakes       Kelloggs    C       100        2    0
# 17                    Corn Pops       Kelloggs    C       110        1    0
# ...

# %% [markdown]
# 5. Create a column called `sodium_grams` equal to `sodium` divided by 1000.

# %%
df["sodium_grams"] = df["sodium"] / 1000

df
# Out:
#                          name            mfr type  calories  protein  fat  \
# 0                   100% Bran        Nabisco    C        70        4    1
# 1           100% Natural Bran    Quaker Oats    C       120        3    5
# 2                    All-Bran       Kelloggs    C        70        4    1
# 3   All-Bran with Extra Fiber       Kelloggs    C        50        4    0
# 4              Almond Delight        Ralston    C       110        2    2
# ..                        ...            ...  ...       ...      ...  ...
# 72                    Triples  General Mills    C       110        2    1
# 73                       Trix  General Mills    C       110        1    1
# 74                 Wheat Chex        Ralston    C       100        3    1
# 75                   Wheaties  General Mills    C       100        3    1
# 76        Wheaties Honey Gold  General Mills    C       110        2    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# ...

# %% [markdown]
# 6. Rename the `shelf` column as `display_shelf`.

# %%
df = df.rename(columns={"shelf": "display_shelf"})

df
# Out:
#                          name            mfr type  calories  protein  fat  \
# 0                   100% Bran        Nabisco    C        70        4    1
# 1           100% Natural Bran    Quaker Oats    C       120        3    5
# 2                    All-Bran       Kelloggs    C        70        4    1
# 3   All-Bran with Extra Fiber       Kelloggs    C        50        4    0
# 4              Almond Delight        Ralston    C       110        2    2
# ..                        ...            ...  ...       ...      ...  ...
# 72                    Triples  General Mills    C       110        2    1
# 73                       Trix  General Mills    C       110        1    1
# 74                 Wheat Chex        Ralston    C       100        3    1
# 75                   Wheaties  General Mills    C       100        3    1
# 76        Wheaties Honey Gold  General Mills    C       110        2    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  display_shelf  weight  \
# ...

# %% [markdown]
# 7. How many cereals have `type == "hot"`?

# %%
df[df["type"] == "H"].shape[0]
# Out:
# 3
